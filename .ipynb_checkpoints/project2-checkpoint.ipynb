# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
oil = pd.read_csv('./data/fish_oil2.csv')

# %% [markdown]
# # EXPLORACIÓN DE DATOS

# %%
# muestra,acido_graso_omega3,acido_graso_omega6,vitamina_a,vitamina_e
oil.head()
# Out:
#    sample  omega3_fatty_acid  omega6_fatty_acid  vitamin_a  vitamin_e
# 0       1               12.5                5.2        120         15
# 1       2               11.2                4.8        110         12
# 2       3               10.8                4.5        100         11
# 3       4               13.1                5.5        125         17
# 4       5               12.3                5.0        115         14

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sample             15 non-null     int64
#  1   omega3_fatty_acid  15 non-null     float64
#  2   omega6_fatty_acid  15 non-null     float64
#  3   vitamin_a          15 non-null     int64
#  4   vitamin_e          15 non-null     int64
# dtypes: float64(2), int64(3)
# memory usage: 728.0 bytes

# %% [markdown]
# # Análisis estadístico

# %%
oil.describe()
# Out:
#           sample  omega3_fatty_acid  omega6_fatty_acid   vitamin_a  vitamin_e
# count  15.000000          15.000000          15.000000   15.000000  15.000000
# mean    8.000000          11.946667           5.046667  111.933333  13.333333
# std     4.472136           0.931870           0.415532   10.102805   2.526055
# min     1.000000          10.300000           4.300000   95.000000   9.000000
# 25%     4.500000          11.450000           4.750000  106.000000  12.000000
# 50%     8.000000          12.000000           5.100000  112.000000  13.000000
# 75%    11.500000          12.550000           5.350000  119.000000  15.000000
# max    15.000000          13.500000           5.700000  130.000000  18.000000

# %% [markdown]
# # Visualización de datos

# %%
sns.set(style = 'whitegrid')
fig, axes = plt.subplots(2,2, figsize = (10,8))
plt.subplots_adjust(hspace = 0.5)
sns.barplot(ax = axes[0,0], data = oil , x = 'sample' , y = 'omega3_fatty_acid')
axes[0,0].set_title('Omega 3')
sns.barplot(ax = axes[0,1], data = oil , x = 'sample' , y = 'omega6_fatty_acid')
axes[0,1].set_title('Omega 6')
sns.barplot(ax = axes[1,0], data = oil , x = 'sample' , y = 'vitamin_a')
axes[1,0].set_title('Vitamin A')
sns.barplot(ax = axes[1,1], data = oil , x = 'sample' , y = 'vitamin_e')
axes[1,1].set_title('Vitamin E')
plt.show()

# %% [markdown]
# # Análisis comparativo

# %%
# Media Aritmetica
oil.mean()
# Out:
# sample                 8.000000
# omega3_fatty_acid     11.946667
# omega6_fatty_acid      5.046667
# vitamin_a            111.933333
# vitamin_e             13.333333
# dtype: float64

# %% [markdown]
# # Análisis de tendencias

# %%
oil['year'] = np.random.choice([2023,2022,2021] , size = len(oil))
oil['month'] = np.random.choice(range(1,13) , size = len(oil))
oil['date'] = pd.to_datetime(oil[['year', 'month']].assign(day = 1))
oil.sort_values('date')
# Out:
#     sample  omega3_fatty_acid  omega6_fatty_acid  vitamin_a  vitamin_e  year  \
# 2        3               10.8                4.5        100         11  2021
# 5        6               11.9                5.3        105         13  2021
# 10      11               11.7                4.3        107         12  2021
# 4        5               12.3                5.0        115         14  2021
# 9       10               12.0                4.6        112         13  2021
# 8        9               13.5                5.1        130         18  2021
# 12      13               10.3                5.4         95          9  2022
# 0        1               12.5                5.2        120         15  2022
# 7        8               10.5                4.7         98         10  2022
# 11      12               12.6                5.6        122         15  2022
# 14      15               12.2                5.1        114         13  2022
# 3        4               13.1                5.5        125         17  2022
# 13      14               11.8                5.7        108         12  2023
# 1        2               11.2                4.8        110         12  2023
# 6        7               12.8                4.9        118         16  2023
#
#     month       date
# 2       2 2021-02-01
# 5       4 2021-04-01
# 10      5 2021-05-01
# 4       6 2021-06-01
# 9       6 2021-06-01
# 8       8 2021-08-01
# 12      3 2022-03-01
# 0       4 2022-04-01
# 7       4 2022-04-01
# 11      5 2022-05-01
# 14     11 2022-11-01
# 3      12 2022-12-01
# 13      7 2023-07-01
# 1       8 2023-08-01
# 6       9 2023-09-01

# %% [markdown]
# # Crear informes interactivo
