# %% [markdown]
# # Importar los datos

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
oil = pd.read_csv('./data/fish_oil.csv')

# %% [markdown]
# # EXPLORACIÓN DE DATOS

# %%
# muestra,acido_graso_omega3,acido_graso_omega6,vitamina_a,vitamina_e
oil.head()
# Out:
#    Muestra  Humedad (%)  Grasa (%)  Proteí­na (%)  Cenizas (%)  EPA (%)  \
# 0        1          4.2       88.5            3.2          1.1     10.2
# 1        2          3.8       92.1            2.5          0.9     12.5
# 2        3          5.1       85.6            4.5          1.3      9.8
# 3        4          4.4       89.8            3.0          1.2     11.0
# 4        5          4.7       87.2            3.8          1.0     10.5
#
#    DHA (%)  Vitamina A (UI/g)  Especie    Calidad  Precio (USD/kg)  \
# 0     15.8               1200   Anchoa    Premium              150
# 1     18.2               1300  Sardina    Premium              160
# 2     14.5               1180    Jurel  EstÃ¡ndar              140
# 3     16.5               1220   Anchoa  EstÃ¡ndar              145
# 4     15.0               1210  Sardina    Premium              155
#
#    Materia Prima (kg)  Contaminante B (mg/g)
# 0                 200                  0.003
# 1                 220                  0.005
# 2                 190                  0.004
# 3                 195                  0.002
# 4                 210                  0.006

# %%
oil.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Muestra                100 non-null    int64
#  1   Humedad (%)            100 non-null    float64
#  2   Grasa (%)              100 non-null    float64
#  3   Proteí­na (%)          100 non-null    float64
#  4   Cenizas (%)            100 non-null    float64
#  5   EPA (%)                100 non-null    float64
#  6   DHA (%)                100 non-null    float64
#  7   Vitamina A (UI/g)      100 non-null    int64
#  8   Especie                100 non-null    object
#  9   Calidad                100 non-null    object
#  10  Precio (USD/kg)        100 non-null    int64
#  11  Materia Prima (kg)     100 non-null    int64
#  12  Contaminante B (mg/g)  100 non-null    float64
# dtypes: float64(7), int64(4), object(2)
# memory usage: 10.3+ KB

# %% [markdown]
# # Limpieza y preparación de datos

# %%
# Renombrar columnas
oil_rename = oil.rename(columns = {'Muestra': 'Sample' , 'Humedad (%)': 'Moisture', 'Grasa (%)': 'Fat', 'Proteína  (%)':'Protein', 'EPA (%)':'EPA', 'DHA (%)':'DHA', 'Cenizas (%)':'Ash', 'Vitamina A (UI/g)':'Vitamin A', 'Especie':'Species','Calidad':' Quality' , 'Precio (USD/kg)':'Price', 'Materia Prima (kg)':'Raw Material' ,'Contaminante B':'Contaminant B'})
oil_rename
# Out:
#     Sample  Moisture   Fat  Proteí­na (%)  Ash   EPA   DHA  Vitamin A  \
# 0        1       4.2  88.5            3.2  1.1  10.2  15.8       1200
# 1        2       3.8  92.1            2.5  0.9  12.5  18.2       1300
# 2        3       5.1  85.6            4.5  1.3   9.8  14.5       1180
# 3        4       4.4  89.8            3.0  1.2  11.0  16.5       1220
# 4        5       4.7  87.2            3.8  1.0  10.5  15.0       1210
# ..     ...       ...   ...            ...  ...   ...   ...        ...
# 95      96       3.9  91.5            2.3  0.8  12.8  19.0       1280
# 96      97       4.8  86.9            4.0  1.1  10.0  14.8       1195
# 97      98       4.1  88.9            3.4  1.0  10.7  15.5       1225
# 98      99       5.3  84.3            4.8  1.4   9.5  14.2       1170
# 99     100       4.6  87.8            3.6  1.2  10.3  15.2       1208
#
#     Species    Quality  Price  Raw Material  Contaminante B (mg/g)
# 0    Anchoa    Premium    150           200                  0.003
# 1   Sardina    Premium    160           220                  0.005
# 2     Jurel  EstÃ¡ndar    140           190                  0.004
# 3    Anchoa  EstÃ¡ndar    145           195                  0.002
# 4   Sardina    Premium    155           210                  0.006
# ..      ...        ...    ...           ...                    ...
# 95    Jurel    Premium    165           225                  0.004
# 96   Anchoa  EstÃ¡ndar    142           193                  0.002
# 97  Sardina  EstÃ¡ndar    148           200                  0.007
# 98    Jurel    Premium    160           215                  0.004
# 99   Anchoa  EstÃ¡ndar    145           195                  0.002
#
# [100 rows x 13 columns]

# %% [markdown]
# EPA: Ácido Eicosapentaenoico. Es un ácido graso omega-3 que se encuentra principalmente en pescados grasos como el salmón, la caballa y el atún. El EPA tiene diversos beneficios para la salud, especialmente en el sistema cardiovascular.
#
# DHA: Ácido Docosahexaenoico. También es un ácido graso omega-3 que se encuentra en alimentos como el pescado y los mariscos. El DHA es esencial para el desarrollo y funcionamiento del cerebro, así como para mantener una buena salud ocular.
#
# UI: Unidades Internacionales. Es una medida utilizada para expresar la cantidad de vitaminas o nutrientes en un suplemento o alimento fortificado. En este caso, podría referirse a la cantidad de EPA y DHA en el aceite de pescado.
#
# USD: Dólar estadounidense. Es la abreviatura de la moneda utilizada en Estados Unidos. En el contexto de la tabla, podría indicar el precio en dólares de venta de la harina o el aceite de pescado.

# %%
# Asegurarse de que los tipos de datos sean adecuados
oil_rename.info()
# En este caso no se realiza cambios de tipo de datos ya que todo esta correctamente dateado
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Sample                 100 non-null    int64
#  1   Moisture               100 non-null    float64
#  2   Fat                    100 non-null    float64
#  3   Proteí­na (%)          100 non-null    float64
#  4   Ash                    100 non-null    float64
#  5   EPA                    100 non-null    float64
#  6   DHA                    100 non-null    float64
#  7   Vitamin A              100 non-null    int64
#  8   Species                100 non-null    object
#  9    Quality               100 non-null    object
#  10  Price                  100 non-null    int64
#  11  Raw Material           100 non-null    int64
#  12  Contaminante B (mg/g)  100 non-null    float64
# dtypes: float64(7), int64(4), object(2)
# memory usage: 10.3+ KB

# %%
# Detectar valores nulos o espacios en blanco
null = oil_rename.isnull()
null
# Out:
#     Sample  Moisture    Fat  Proteí­na (%)    Ash    EPA    DHA  Vitamin A  \
# 0    False     False  False          False  False  False  False      False
# 1    False     False  False          False  False  False  False      False
# 2    False     False  False          False  False  False  False      False
# 3    False     False  False          False  False  False  False      False
# 4    False     False  False          False  False  False  False      False
# ..     ...       ...    ...            ...    ...    ...    ...        ...
# 95   False     False  False          False  False  False  False      False
# 96   False     False  False          False  False  False  False      False
# 97   False     False  False          False  False  False  False      False
# 98   False     False  False          False  False  False  False      False
# 99   False     False  False          False  False  False  False      False
#
#     Species   Quality  Price  Raw Material  Contaminante B (mg/g)
# 0     False     False  False         False                  False
# 1     False     False  False         False                  False
# 2     False     False  False         False                  False
# 3     False     False  False         False                  False
# 4     False     False  False         False                  False
# ..      ...       ...    ...           ...                    ...
# 95    False     False  False         False                  False
# 96    False     False  False         False                  False
# 97    False     False  False         False                  False
# 98    False     False  False         False                  False
# 99    False     False  False         False                  False
#
# [100 rows x 13 columns]

# %%
blank = oil_rename == ' '
blank
# Out:
#     Sample  Moisture    Fat  Proteí­na (%)    Ash    EPA    DHA  Vitamin A  \
# 0    False     False  False          False  False  False  False      False
# 1    False     False  False          False  False  False  False      False
# 2    False     False  False          False  False  False  False      False
# 3    False     False  False          False  False  False  False      False
# 4    False     False  False          False  False  False  False      False
# ..     ...       ...    ...            ...    ...    ...    ...        ...
# 95   False     False  False          False  False  False  False      False
# 96   False     False  False          False  False  False  False      False
# 97   False     False  False          False  False  False  False      False
# 98   False     False  False          False  False  False  False      False
# 99   False     False  False          False  False  False  False      False
#
#     Species   Quality  Price  Raw Material  Contaminante B (mg/g)
# 0     False     False  False         False                  False
# 1     False     False  False         False                  False
# 2     False     False  False         False                  False
# 3     False     False  False         False                  False
# 4     False     False  False         False                  False
# ..      ...       ...    ...           ...                    ...
# 95    False     False  False         False                  False
# 96    False     False  False         False                  False
# 97    False     False  False         False                  False
# 98    False     False  False         False                  False
# 99    False     False  False         False                  False
#
# [100 rows x 13 columns]

# %%
# Contar los valores nulos en cada columna
nulls = oil_rename.isnull().sum()
nulls
# Out:
# Sample                   0
# Moisture                 0
# Fat                      0
# Proteí­na (%)            0
# Ash                      0
# EPA                      0
# DHA                      0
# Vitamin A                0
# Species                  0
#  Quality                 0
# Price                    0
# Raw Material             0
# Contaminante B (mg/g)    0
# dtype: int64

# %%
# Contar los espacios en blanco en cada columna
blanks = oil_rename.apply(lambda x: x.astype(str).str.isspace().sum())
blanks
# Out:
# Sample                   0
# Moisture                 0
# Fat                      0
# Proteí­na (%)            0
# Ash                      0
# EPA                      0
# DHA                      0
# Vitamin A                0
# Species                  0
#  Quality                 0
# Price                    0
# Raw Material             0
# Contaminante B (mg/g)    0
# dtype: int64

# %% [markdown]
# # Análisis estadísticos descriptivos

# %%
descripcion = oil_rename.describe()
descripcion
# Out:
#            Sample    Moisture         Fat  Proteí­na (%)        Ash  \
# count  100.000000  100.000000  100.000000     100.000000  100.00000
# mean    50.500000    4.504000   88.266000       3.516000    1.08500
# std     29.011492    0.436913    2.086088       0.701761    0.15333
# min      1.000000    3.800000   84.300000       2.300000    0.80000
# 25%     25.750000    4.200000   86.900000       3.100000    1.00000
# 50%     50.500000    4.450000   88.400000       3.400000    1.10000
# 75%     75.250000    4.800000   89.600000       4.000000    1.20000
# max    100.000000    5.300000   92.100000       4.800000    1.40000
#
#               EPA       DHA   Vitamin A       Price  Raw Material  \
# count  100.000000  100.0000   100.00000  100.000000    100.000000
# mean    10.688000   15.7720  1217.58000  151.050000    204.280000
# std      0.934013    1.3375    33.98579    7.622899     10.493942
# min      9.500000   14.2000  1170.00000  140.000000    190.000000
# 25%     10.100000   14.9000  1195.00000  145.000000    195.000000
# 50%     10.450000   15.3500  1210.00000  148.000000    200.000000
# 75%     11.000000   16.0000  1230.00000  160.000000    215.000000
# max     12.800000   19.0000  1300.00000  165.000000    225.000000
#
#        Contaminante B (mg/g)
# count              100.00000
# mean                 0.00409
# std                  0.00181
# min                  0.00200
# 25%                  0.00200
# 50%                  0.00400
# 75%                  0.00600
# max                  0.00700

# %% [markdown]
# # 1. Análisis de calidad

# %%
# Graficar la evolución de los indicadores de calidad a lo largo del tiempo
plt.figure(figsize=(10, 6))
sns.lineplot(data=oil_rename[['EPA', 'DHA']], markers=True)
plt.xlabel('Sample')
plt.ylabel('Quality')
plt.title('Evolution of EPA and DHA in fish oil')
plt.show()

# %%
# Identificar correlaciones entre las diferentes variables de calidad
correlations = oil_rename[['EPA', 'DHA']].corr()
correlations
# Out:
#           EPA       DHA
# EPA  1.000000  0.978827
# DHA  0.978827  1.000000

# %% [markdown]
# # Análisis de Componentes Principales (PCA)

# %% [markdown]
# # Visualización de datos

# %%
sns.set(style = 'whitegrid')
fig, axes = plt.subplots(2,2, figsize = (10,8))
plt.subplots_adjust(hspace = 0.5)
sns.barplot(ax = axes[0,0], data = oil , x = 'sample' , y = 'omega3_fatty_acid')
axes[0,0].set_title('Omega 3')
sns.barplot(ax = axes[0,1], data = oil , x = 'sample' , y = 'omega6_fatty_acid')
axes[0,1].set_title('Omega 6')
sns.barplot(ax = axes[1,0], data = oil , x = 'sample' , y = 'vitamin_a')
axes[1,0].set_title('Vitamin A')
sns.barplot(ax = axes[1,1], data = oil , x = 'sample' , y = 'vitamin_e')
axes[1,1].set_title('Vitamin E')
plt.show()

# %% [markdown]
# # Análisis comparativo

# %%
# Media Aritmetica
comparison = oil.mean()
comparison
# Out:
# sample                               8.0
# omega3_fatty_acid              11.946667
# omega6_fatty_acid               5.046667
# vitamin_a                     111.933333
# vitamin_e                      13.333333
# year                         2022.133333
# month                           6.533333
# date                 2022-08-05 04:48:00
# dtype: object

# %% [markdown]
# # Análisis de tendencias

# %%
oil['year'] = np.random.choice([2023,2022,2021] , size = len(oil))
oil['month'] = np.random.choice(range(1,13) , size = len(oil))
oil['date'] = pd.to_datetime(oil[['year', 'month']].assign(day = 1))
oil.sort_values('date')
# Out:
#     sample  omega3_fatty_acid  omega6_fatty_acid  vitamin_a  vitamin_e  year  \
# 1        2               11.2                4.8        110         12  2021
# 13      14               11.8                5.7        108         12  2021
# 0        1               12.5                5.2        120         15  2021
# 5        6               11.9                5.3        105         13  2021
# 7        8               10.5                4.7         98         10  2021
# 8        9               13.5                5.1        130         18  2022
# 3        4               13.1                5.5        125         17  2022
# 10      11               11.7                4.3        107         12  2022
# 12      13               10.3                5.4         95          9  2023
# 4        5               12.3                5.0        115         14  2023
# 6        7               12.8                4.9        118         16  2023
# 11      12               12.6                5.6        122         15  2023
# 2        3               10.8                4.5        100         11  2023
# 9       10               12.0                4.6        112         13  2023
# 14      15               12.2                5.1        114         13  2023
#
#     month       date
# 1       2 2021-02-01
# 13      3 2021-03-01
# 0       7 2021-07-01
# 5       7 2021-07-01
# 7      12 2021-12-01
# 8       4 2022-04-01
# 3       6 2022-06-01
# 10     11 2022-11-01
# 12      1 2023-01-01
# 4       2 2023-02-01
# 6       7 2023-07-01
# 11      7 2023-07-01
# 2       8 2023-08-01
# 9       9 2023-09-01
# 14     12 2023-12-01

# %% [markdown]
# # Análisis de relaciones

# %% [markdown]
# correlation_matrix = df.corr(): Utilizamos el método corr() en el DataFrame df para calcular la matriz de correlación. La función corr() calcula la correlación entre todas las columnas del DataFrame y devuelve una matriz que muestra las correlaciones entre todas las combinaciones de pares de variables. La matriz de correlación es una tabla cuadrada simétrica, donde los valores en la diagonal principal son siempre 1 (correlación perfecta) y los valores fuera de la diagonal representan la correlación entre las variables.

# %%
correlation_matrix = oil.corr()

# %% [markdown]
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm'): Usamos la función heatmap() de la biblioteca seaborn para crear un mapa de calor que representa visualmente la matriz de correlación. El mapa de calor utiliza colores para mostrar la intensidad de la correlación entre las variables. Los valores más altos de correlación se muestran en colores más oscuros, mientras que los valores más bajos se muestran en colores más claros. Establecemos annot=True para mostrar los valores de correlación en cada celda del mapa de calor.
# En particular, coolwarm es uno de los mapas de colores predefinidos disponibles en seaborn. Este mapa de colores se caracteriza por tener una transición suave entre colores fríos y cálidos. Los valores bajos de correlación se representan en tonos de azul (colores fríos), mientras que los valores altos de correlación se representan en tonos de rojo (colores cálidos). Los valores neutros o cercanos a cero se representan en tonos blancos o grises.

# %%
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Maxtrix')
plt.show()

# %% [markdown]
# # Informe y presentación de resultados

# %% [markdown]
# report = pd.DataFrame({...}) se utiliza para crear un DataFrame llamado report que resume los resultados de varios análisis realizados en los datos. Permíteme explicarte en detalle cada parte de esta línea:
#
# 'Statistics': statistics.loc['mean'] crea una columna llamada "Statistics" en el DataFrame report y asigna los valores de la fila "mean" de la variable statistics. Esta línea extrae las estadísticas de promedio (mean) para cada columna del DataFrame original y las agrega al informe.
#
# 'Comparison': comparison crea otra columna llamada "Comparison" en el DataFrame report y asigna los valores de la variable comparison. Aquí, comparison es un objeto que contiene el promedio de las columnas "protein" y "fat" del DataFrame original. Esto se calculó previamente utilizando df[['omega3_fatty_acid', 'omega6_fatty_acid']].mean().
#
# 'Correlation Omega3 vs Omega6': correlation_matrix.loc['omega3_fatty_acid', 'omega6_fatty_acid'] crea una tercera columna llamada "Correlation Protein vs Fat" en el DataFrame report y asigna el valor de correlación entre las variables "protein" y "fat" de la matriz de correlación (correlation_matrix). Esta línea extrae específicamente el valor de correlación entre esas dos variables.

# %%
report = pd.DataFrame({
    'Statistics': statistics.loc['mean'],
    'Comparison': comparison,
    'Correlation Omega 3 vs Omega 6': correlation_matrix.loc['omega3_fatty_acid', 'omega6_fatty_acid']
})
report
# Out:
#                             Statistics           Comparison  \
# sample                             8.0                  8.0
# omega3_fatty_acid            11.946667            11.946667
# omega6_fatty_acid             5.046667             5.046667
# vitamin_a                   111.933333           111.933333
# vitamin_e                    13.333333            13.333333
# year                       2022.133333          2022.133333
# month                         6.533333             6.533333
# date               2022-08-05 04:48:00  2022-08-05 04:48:00
#
#                    Correlation Omega 3 vs Omega 6
# sample                                   0.314942
# omega3_fatty_acid                        0.314942
# omega6_fatty_acid                        0.314942
# vitamin_a                                0.314942
# vitamin_e                                0.314942
# year                                     0.314942
# month                                    0.314942
# date                                     0.314942
